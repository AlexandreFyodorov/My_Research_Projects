# %% [markdown]
# # Аналитический отчёт по результатам фундаментального скрининга сектора Агропрома и химии
#
# **Дата анализа:** 14 марта 2026 г.
# **Выборка:** 15 компаний агропромышленного комплекса и химической промышленности, прошедших фильтр ликвидности (оборот ≥ 1 млн руб., заявки ≥ 100).
# **Фавориты (выбраны пользователем):** **PHOR, GCHE, NKHP, AKRN, KAZT, ABRD, KLVZ, RAGR, AQUA**.
#
# ## 1. Введение
#
# Цель анализа – оценка инвестиционной привлекательности компаний российского агропромышленного комплекса и химической отрасли, представленных в файле и отобранных пользователем. В выборку вошли ведущие производители минеральных удобрений, крупные агрохолдинги, производители продуктов питания и напитков, а также компании, связанные с переработкой сельхозпродукции и аквакультурой.
#
# В работе использованы данные из предоставленного файла (исторические данные за 2020-2025 гг. и последние 12 месяцев – LTM), а также актуальная информация из открытых источников для оценки перспектив компаний на ближайшие 3 года.
#
# ## 2. Краткое описание компаний
#
# | Тикер | Название | Основная деятельность |
# |-------|----------|----------------------|
# | **PHOR** | ФосАгро | Ведущий мировой производитель фосфорсодержащих удобрений, вертикально-интегрированная компания |
# | **GCHE** | Группа Черкизово | Крупный производитель мяса птицы, свинины и комбикормов |
# | **NKHP** | НКХП (Новороссийский комбинат хлебопродуктов) | Ключевой зерновой терминал в порту Новороссийска, перевалка пшеницы, ячменя, кукурузы на экспорт |
# | **AKRN** | Акрон | Один из крупнейших мировых производителей минеральных удобрений |
# | **KAZT** | КуйбышевАзот | Производитель химической продукции (капролактам, полиамиды, удобрения) |
# | **ABRD** | Абрау-Дюрсо | Лидер российского рынка игристых вин, развивает туристическое и девелоперское направления |
# | **KLVZ** | КЛВЗ Кристалл | Производитель алкогольной продукции (ликёро-водочные изделия, коктейли) |
# | **RAGR** | Русагро | Крупный агрохолдинг с вертикальной интеграцией (сахар, масложировая продукция, мясо, сельхозкультуры) |
# | **AQUA** | Русская Аквакультура | Крупнейший производитель товарной лососёвой рыбы (форель, сёмга) в России |
#
# ## 3. Детальный анализ фаворитов
#
# ### 3.1. PHOR (ФосАгро)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 9.37 | 5.81 | 4.54 | 8.20 | 8.20 | н/д | 8.04 |
# | P/B | 3.83 | 4.64 | 4.24 | 5.74 | 5.10 | н/д | 4.34 |
# | EV/EBITDA | 6.50 | 4.71 | 3.90 | 5.86 | 6.47 | н/д | 5.42 |
# | NetDebt/EBITDA | 1.76 | 0.77 | 0.69 | 1.20 | 1.81 | н/д | 1.14 |
#
# **Анализ динамики:**
# В 2021-2022 годах наблюдалось существенное улучшение мультипликаторов благодаря взрывному росту цен на удобрения на мировых рынках. P/E снизился до исторических минимумов (4.5-5.8), что указывало на глубокую недооценку при высокой прибыли. В 2023 году произошла коррекция цен на удобрения, что отразилось в росте P/E до 8.2. В 2024-2025 годах показатели стабилизировались: P/E держится в диапазоне 8-9, P/B вырос до 5.1 (дорогая оценка относительно баланса), NetDebt/EBITDA увеличился до 1.8, но остаётся в комфортной зоне.
#
# **Свежие данные и перспективы:**
# В марте 2026 года ФосАгро успешно разместила выпуск облигаций в юанях на 1,5 млрд по ставке 8,00% годовых, что на 2,5 п.п. ниже предыдущего размещения. Высокий спрос и присвоение рейтинга ruAAA подтверждают доверие инвесторов к кредитному качеству компании [citation:1]. Финансовые результаты за 1 полугодие 2025 показывают восстановление: выручка +23,6% г/г, чистая прибыль +51,9% г/г [citation:10]. Стратегия государства по снижению доли зерна в агроэкспорте до 25% к 2030 году в пользу продукции с высокой добавленной стоимостью создаёт долгосрочный спрос на удобрения [citation:8].
#
# **Вывод по тикеру:**
# ФосАгро – высококачественный эмитент с сильным кредитным рейтингом и восстановлением финансовых показателей. Текущие мультипликаторы (P/E ~8, EV/EBITDA ~5.4) указывают на справедливую оценку. Компания остаётся бенефициаром глобального спроса на продовольствие и удобрения. Рекомендуется для консервативных инвесторов, ориентированных на долгосрочный рост и дивиденды.
#
# ### 3.2. GCHE (Группа Черкизово)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | - | 7.40 | 7.40 | 6.32 | 8.85 | 7.20 | 8.52 |
# | P/B | 0.78 | 1.65 | 1.34 | 1.55 | 1.55 | 1.00 | 1.18 |
# | EV/EBITDA | 5.07 | 6.72 | 6.80 | 5.37 | 6.75 | 4.84 | 5.30 |
# | NetDebt/EBITDA | 2.48 | 2.48 | 3.01 | 1.91 | 2.87 | 2.36 | 2.36 |
#
# **Анализ динамики:**
# Черкизово демонстрирует умеренную волатильность мультипликаторов. P/E колебался в диапазоне 6-9, достигнув минимума в 2023 году (6.32) и максимума в 2024 (8.85). P/B стабильно выше 1, кроме 2020 года, что указывает на рыночную оценку выше балансовой стоимости. Долговая нагрузка (NetDebt/EBITDA) остаётся в допустимых пределах (1.9-3.0), хотя в 2024-2025 годах наблюдается рост до 2.87-2.36. EV/EBITDA держится в зоне 5-7, что близко к справедливым значениям.
#
# **Свежие данные и перспективы:**
# По данным на март 2026 года, капитализация компании составляет 158,8 млрд руб., чистая прибыль за 2025 год – 13,3 млрд руб. (-9,4% г/г). В 2025 году дивиденды не выплачивались [citation:2]. Компания остаётся крупным игроком на рынке мяса, но сталкивается с давлением на маржинальность из-за высокой стоимости кредитов и стабильных цен на продукцию.
#
# **Вывод по тикеру:**
# Черкизово – стабильный, но не выдающийся актив. Рост мультипликаторов в 2024-2025 годах указывает на некоторое удорожание, но рентабельность остаётся под давлением. Рекомендуется для диверсификации в портфеле с умеренным апсайдом.
#
# ### 3.3. NKHP (НКХП)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 3.50 | 4.85 | 4.02 | 7.90 | 6.77 | н/д | 6.10 |
# | P/B | 0.96 | 1.36 | 0.98 | 1.70 | 1.74 | н/д | 1.13 |
# | EV/EBITDA | 2.29 | 2.03 | 1.46 | 4.51 | 2.97 | н/д | 2.29 |
# | NetDebt/EBITDA | -1.89 | -0.78 | -1.09 | -1.34 | -1.61 | н/д | -1.89 |
#
# **Анализ динамики:**
# Ключевая особенность НКХП – стабильно отрицательный чистый долг на протяжении всего периода, что означает наличие значительной денежной подушки. P/E достиг минимума в 2020 году (3.5) и максимума в 2023 (7.9), после чего снизился до 6.1. EV/EBITDA также демонстрирует низкие значения (1.5-4.5), что указывает на недооценку бизнеса.
#
# **Свежие данные и перспективы:**
# В 2025 году компания столкнулась с ухудшением показателей: выручка снизилась на 49% г/г, чистая прибыль – на 60% из-за введения экспортных квот и высокого курса рубля, сделавшего российскую пшеницу неконкурентной. Однако компания реализует масштабную программу расширения: к 2026-2027 годам мощность перевалки вырастет до 11,6 млн тонн, к концу 2028 года – до 13 млн тонн. Ослабление рубля до 90-95 за доллар станет ключевым драйвером восстановления [citation:3].
#
# **Вывод по тикеру:**
# НКХП – интересная ставка на ослабление рубля и восстановление экспорта зерна. Отрицательный долг и инвестиционная программа создают потенциал роста. Текущая слабость – временная, вызванная макрофакторами. Рекомендуется для инвесторов, готовых к циклическим колебаниям.
#
# ### 3.4. AKRN (Акрон)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 62.7 | 3.75 | 3.57 | 2.36 | 21.5 | н/д | 15.7 |
# | P/B | 5.64 | 0.69 | 0.52 | 0.58 | 3.24 | н/д | 3.35 |
# | EV/EBITDA | 9.64 | 3.63 | 4.18 | 1.53 | 12.5 | н/д | 9.77 |
# | NetDebt/EBITDA | 2.82 | 2.82 | 0.37 | 0.66 | 1.70 | н/д | 1.36 |
#
# **Анализ динамики:**
# Акрон показал экстремальную волатильность мультипликаторов. В 2021-2023 годах наблюдалась глубокая недооценка (P/E 2.4-3.8) на фоне высоких цен на удобрения. В 2024 году произошёл резкий скачок P/E до 21.5, что отражает либо падение прибыли, либо существенный рост цены акций. Долговая нагрузка остаётся низкой на всём периоде (NetDebt/EBITDA < 2).
#
# **Свежие данные и перспективы:**
# По данным на 2024 год, капитализация Акрона составляет 733 млрд руб., чистая прибыль снизилась на 45,7% г/г до 15,8 млрд руб. [citation:4]. Компания, как и ФосАгро, выигрывает от мирового спроса на удобрения, но волатильность прибыли остаётся высокой.
#
# **Вывод по тикеру:**
# Акрон – циклический актив с высокой волатильностью мультипликаторов. Текущая оценка (P/E 15.7) выше исторических минимумов, но долговая нагрузка низкая. Рекомендуется для инвесторов с высокой толерантностью к риску, готовых к циклическим колебаниям.
#
# ### 3.5. KAZT (КуйбышевАзот)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 51.5 | 4.37 | 2.79 | 8.83 | 6.63 | н/д | 8.30 |
# | P/B | 1.25 | 2.04 | 1.33 | 1.36 | 0.90 | н/д | 0.82 |
# | EV/EBITDA | 6.13 | 3.32 | 2.33 | 4.97 | 6.09 | н/д | 5.16 |
# | NetDebt/EBITDA | 2.24 | 0.17 | -0.38 | -0.56 | 1.16 | н/д | 0.61 |
#
# **Анализ динамики:**
# КуйбышевАзот также подвержен циклическим колебаниям. Минимальные значения P/E (2.8) достигнуты в 2022 году, после чего произошёл рост до 8.8 в 2023 и снижение до 6.6-8.3 в 2024-2025. P/B снизился ниже 1 в 2024-2025, что указывает на недооценку относительно баланса. Долговая нагрузка остаётся низкой, в отдельные годы была отрицательной.
#
# **Свежие данные и перспективы:**
# В декабре 2025 года совет директоров утвердил бюджет и план подготовки к годовому собранию акционеров на 2026 год [citation:5]. Компания демонстрирует устойчивость, но значимых катализаторов роста не видно.
#
# **Вывод по тикеру:**
# КуйбышевАзот – стабильный представитель химической отрасли с низким долгом и P/B < 1. Текущая оценка привлекательна для консервативных инвесторов, ищущих недооценённые активы.
#
# ### 3.6. ABRD (Абрау-Дюрсо)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 17.8 | 14.0 | 10.7 | 20.2 | 10.3 | н/д | 12.2 |
# | P/B | 1.93 | 1.69 | 1.49 | 1.93 | 1.05 | н/д | 1.17 |
# | EV/EBITDA | 12.5 | 8.56 | 7.65 | 11.9 | 6.41 | н/д | 8.41 |
# | NetDebt/EBITDA | 3.07 | 2.12 | 2.11 | 3.01 | 2.01 | н/д | 3.01 |
#
# **Анализ динамики:**
# Абрау-Дюрсо показывает умеренную волатильность. P/E колеблется в диапазоне 10-20, достигнув минимума в 2022 и 2024 годах (10.7-10.3). P/B снизился до 1.05 в 2024, что близко к балансовой стоимости. Основной риск – высокая долговая нагрузка: NetDebt/EBITDA стабильно держится выше 2, достигая 3.0 в отдельные периоды.
#
# **Свежие данные и перспективы:**
# Компания демонстрирует рост выручки (до 19,6 млрд в 2024) и хорошую рентабельность (EBITDA-маржа 21%), но сталкивается с проблемами денежного потока: отрицательный операционный поток и FCF, высокие процентные расходы [citation:6]. Потенциальный катализатор – выход на индийский рынок. Техническая картина показывает ранние сигналы разворота [citation:6].
#
# **Вывод по тикеру:**
# Абрау-Дюрсо – привлекательный по бренду и маржинальности бизнес, но отягощённый долгами и проблемами с денежными потоками. Рекомендуется для осторожных инвесторов с контролем долговой нагрузки и вниманием к новостям об экспортных контрактах.
#
# ### 3.7. KLVZ (КЛВЗ Кристалл)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | - | - | - | - | 33.5 | н/д | 27.9 |
# | P/B | - | - | - | - | 2.91 | н/д | 2.42 |
# | EV/EBITDA | - | - | - | - | 10.1 | н/д | - |
# | NetDebt/EBITDA | - | - | - | - | 2.75 | н/д | - |
#
# **Примечание:** данные за 2020-2023 отсутствуют в файле.
#
# **Анализ динамики:**
# По доступным данным за 2024 год, компания оценивается дорого: P/E 33.5, P/B 2.9, EV/EBITDA 10.1. Долговая нагрузка умеренная (NetDebt/EBITDA 2.75).
#
# **Свежие данные и перспективы:**
# КЛВЗ Кристалл рассчитывает увеличить выручку на 5% в 2026 году за счёт выпуска нового коктейля и загрузки новой баночной линии розлива. Компания планирует поставить на внешние рынки не менее 1 млн банок нового продукта [citation:7].
#
# **Вывод по тикеру:**
# Высокая оценка (P/E > 25) делает акции KLVZ дорогими относительно прибыли. Рост выручки ожидается скромный (5%). Рекомендуется только для спекулятивных инвесторов с пониманием рисков переоценки.
#
# ### 3.8. RAGR (Русагро)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 5.34 | 5.34 | 4.05 | 5.36 | 4.10 | 5.78 | 6.01 |
# | P/B | 1.51 | 1.51 | 0.84 | 1.13 | 0.71 | 0.47 | 0.49 |
# | EV/EBITDA | 6.97 | 6.97 | 8.13 | 5.11 | 5.20 | 5.17 | 5.24 |
# | NetDebt/EBITDA | 3.08 | 3.08 | 5.71 | 1.83 | 2.41 | 3.25 | 3.25 |
#
# **Анализ динамики:**
# Русагро показывает смешанную динамику. P/E стабильно низкий (4-6), что указывает на недооценку. P/B снижался с 1.5 до 0.47 в 2025 году – глубокая недооценка относительно баланса. Долговая нагрузка резко выросла в 2022 году (NetDebt/EBITDA 5.71), но затем снизилась до 2.4-3.25. EV/EBITDA держится в диапазоне 5-8.
#
# **Свежие данные и перспективы:**
# Компания находится в центре корпоративной трансформации: кипрская структура ROS AGRO PLC отстранена от управления, основатель под арестом. Активы могут перейти под контроль государства или квазигосударственных структур. Бизнес продолжает работать, выручка растёт, долг под контролем, но корпоративные риски создают колоссальный дисконт в цене [citation:8]. Вертикальная интеграция (от поля до прилавка) соответствует государственной стратегии снижения доли сырья в экспорте [citation:8].
#
# **Вывод по тикеру:**
# Русагро – высокорисковый, но потенциально высокодоходный актив. Неопределённость контроля создаёт дисконт, но операционные показатели сильны. Рекомендуется для инвесторов с высокой толерантностью к риску, готовых к длительному разрешению корпоративного конфликта.
#
# ### 3.9. AQUA (Русская Аквакультура)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 3.41 | 5.08 | 5.08 | 8.14 | 5.15 | н/д | 3.39 |
# | P/B | 1.27 | 1.97 | 1.97 | 1.92 | 1.26 | н/д | 1.26 |
# | EV/EBITDA | 7.45 | 5.09 | 5.09 | 6.87 | 5.27 | н/д | 7.41 |
# | NetDebt/EBITDA | 1.83 | 1.04 | 1.04 | 1.06 | 1.01 | н/д | 1.83 |
#
# **Анализ динамики:**
# AQUA демонстрирует низкие мультипликаторы: P/E в диапазоне 3-8, P/B 1.3-2.0. Долговая нагрузка остаётся комфортной (NetDebt/EBITDA < 2). В 2023 году P/E вырос до 8.14, но в 2024-2025 снизился до 5.15-3.39, указывая на падение прибыли.
#
# **Свежие данные и перспективы:**
# 2025 год стал тяжёлым для компании: массовая гибель рыбы в 2024 году из-за паразитов и погоды привела к убытку от переоценки биологических активов в 8,3 млрд руб. Добавился сильный рубль, ударивший по экспортной выручке. Цикл восстановления биомассы занимает 1,5-2 года, поэтому к середине 2026 года можно ждать возобновления объёмов. Компания провела рекордное зарыбление в 2025 году [citation:9].
#
# **Вывод по тикеру:**
# AQUA – ставка на восстановительный цикл. Текущая слабость обусловлена разовыми биологическими факторами, а не структурными проблемами. Низкий долг и потенциал удвоения финансовых результатов при восстановлении делают компанию привлекательной для долгосрочных инвесторов с горизонтом 2-3 года.
#
# ## 4. Сводная таблица текущих мультипликаторов (LTM)
#
# | Тикер | P/E | P/B | EV/EBITDA | NetDebt/EBITDA | ROE, % |
# |-------|-----|-----|-----------|----------------|--------|
# | **PHOR** | 8.04 | 4.34 | 5.42 | 1.14 | 53.3 |
# | **GCHE** | 8.52 | 1.18 | 5.30 | 2.36 | 13.0 |
# | **NKHP** | 6.10 | 1.13 | 2.29 | -1.89 | 25.5 |
# | **AKRN** | 15.7 | 3.35 | 9.77 | 1.36 | 21.3 |
# | **KAZT** | 8.30 | 0.82 | 5.16 | 0.61 | 9.7 |
# | **ABRD** | 12.2 | 1.17 | 8.41 | 3.01 | 9.6 |
# | **KLVZ** | 27.9 | 2.42 | - | 2.75 | 4.7 |
# | **RAGR** | 6.01 | 0.49 | 5.24 | 3.25 | 14.7 |
# | **AQUA** | 3.39 | 1.26 | 7.41 | 1.83 | 36.3 |
#
# ## 5. Выводы и рекомендации
#
# ### 5.1. Лидеры по совокупности факторов
#
# - **PHOR (ФосАгро)** – наилучший выбор в секторе: высокая рентабельность (ROE 53%), умеренный долг, сильное кредитное качество, восстановление финансовых показателей. Рекомендуется для консервативных и умеренно-рисковых портфелей.
# - **NKHP (НКХП)** – уникальная компания с отрицательным долгом и потенциалом роста на ослаблении рубля и расширении мощностей. Рекомендуется для инвесторов, делающих ставку на макроэкономические факторы.
# - **KAZT (КуйбышевАзот)** – недооценка по P/B (0.82) при низком долге и стабильном бизнесе. Рекомендуется для консервативных инвесторов, ищущих недооценённые активы.
# - **AQUA (Русская Аквакультура)** – ставка на восстановительный цикл после биологического кризиса. Низкий P/E (3.4) и потенциал удвоения прибыли. Рекомендуется для долгосрочных инвесторов с горизонтом 2-3 года.
#
# ### 5.2. Умеренный интерес
#
# - **GCHE (Черкизово)** – стабильный, но не выдающийся бизнес. P/E 8.5, ROE 13%. Рекомендуется для диверсификации.
# - **AKRN (Акрон)** – высокая волатильность мультипликаторов, текущая оценка выше исторических минимумов. Рекомендуется только для инвесторов, готовых к циклическим колебаниям.
#
# ### 5.3. Высокорисковые / требующие осторожности
#
# - **RAGR (Русагро)** – высокий корпоративный риск из-за смены контроля. Операционные показатели сильны, но неопределённость создаёт дисконт. Рекомендуется для агрессивных инвесторов с чётким ограничением доли в портфеле.
# - **ABRD (Абрау-Дюрсо)** – высокая долговая нагрузка (NetDebt/EBITDA 3.01) и отрицательные денежные потоки. Требует контроля долга и новостей об экспортных контрактах.
# - **KLVZ (КЛВЗ Кристалл)** – дорогая оценка (P/E 27.9) при скромных перспективах роста. Не рекомендуется к покупке.
#
# ## 6. Перспективы сектора на 2026-2029 гг.
#
# - **Минеральные удобрения (PHOR, AKRN)** – останутся бенефициарами глобального спроса на продовольствие. Государственная стратегия смещения экспорта в сторону продукции с высокой добавленной стоимостью потребует увеличения применения удобрений [citation:8].
# - **Перевалка зерна (NKHP)** – восстановление экспорта при ослаблении рубля и снятии квот. Расширение мощностей создаёт потенциал роста.
# - **Продукты питания с высокой добавленной стоимостью (GCHE, RAGR)** – соответствуют государственной стратегии, но маржинальность остаётся под давлением высокой стоимости кредитов.
# - **Потребительский сектор (ABRD, KLVZ)** – чувствителен к доходам населения, требует контроля долговой нагрузки.
# - **Аквакультура (AQUA)** – восстановление после биологического кризиса, потенциал роста при нормализации биологических циклов.
# - **Риски:** высокая ключевая ставка, волатильность рубля, экспортные пошлины и квоты, биологические риски, корпоративные конфликты.
#
# ## 7. Когда произвести очередной скрининг?
#
# Рекомендуется провести следующий скрининг **через 6 месяцев (сентябрь 2026)** с акцентом на:
#
# - динамику долговой нагрузки ABRD и GCHE;
# - восстановление операционных показателей NKHP и AQUA;
# - разрешение корпоративной ситуации в RAGR;
# - финансовые результаты PHOR и подтверждение дивидендных выплат;
# - макроэкономические сигналы (курс рубля, ставка ЦБ, экспортные пошлины, урожай).
#
# ---

# %% [markdown]
# <div class="alert alert-info">
# </div>

# %%
# =============================================================================
# БЛОК АНАЛИЗА ДИНАМИКИ МУЛЬТИПЛИКАТОРОВ ПО СЕКТОРУ (2020-2025)
# =============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import os
import warnings
warnings.filterwarnings('ignore')

# -------------------- НАСТРОЙКИ --------------------
YEARS = [2020, 2021, 2022, 2023, 2024, 2025]  # анализируемые годы
INPUT_YEARLY_FILE = 'C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/df_fund_yearly.xlsx'
SECTOR_FILE = 'C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Sector_updated.xlsx'  # файл с секторами
OUTPUT_PATH = 'C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Analitika/'
SECTOR_LIST = [
    'Агропром, химия'
]

# Список показателей для анализа (можно расширить или сократить)
METRICS = [
    'Revenue', 'OperatingProfit', 'EBITDA', 'NetIncome',
    'CAPEX', 'FCF', 'OperExpenses', 'Interest',
    'Assets', 'Debt', 'Cash', 'NetDebt',
    'Price', 'Shares', 'MarketCap', 'EPS', 'BVPS',
    'ROE_raw', 'ROA_raw', 'PE_raw', 'PS_raw', 'PB_raw',
    'EVEBITDA_raw', 'DebtEBITDA_raw'
]

# -------------------- ЗАГРУЗКА ДАННЫХ --------------------
print("Загрузка годовых данных...")
yearly_dfs = {}
for year in YEARS:
    try:
        df_year = pd.read_excel(INPUT_YEARLY_FILE, sheet_name=str(year), index_col=0, engine='openpyxl')
        # Убираем возможный дублирующийся индекс, если колонка 'A' попала как данные
        if 'A' in df_year.columns:
            df_year = df_year.drop(columns=['A'])
        yearly_dfs[year] = df_year
        print(f"  {year}: {df_year.shape[0]} строк, {df_year.shape[1]} колонок")
    except Exception as e:
        print(f"  Ошибка загрузки листа {year}: {e}")
        yearly_dfs[year] = pd.DataFrame()

# -------------------- ЗАГРУЗКА СЕКТОРОВ --------------------
print("\nЗагрузка секторов...")
try:
    sector_df = pd.read_excel(SECTOR_FILE, sheet_name='Sector', engine='openpyxl')
    sector_df = sector_df[['Код инструмента', 'Категории']].copy()
    sector_df.dropna(inplace=True)
    sector_df['Код инструмента'] = sector_df['Код инструмента'].astype(str).str.strip()
    sector_df = sector_df.drop_duplicates(subset=['Код инструмента'])
    sector_mapping = dict(zip(sector_df['Код инструмента'], sector_df['Категории']))
    print(f"Загружено {len(sector_mapping)} записей о секторах.")
except Exception as e:
    print(f"Ошибка загрузки секторов: {e}")
    sector_mapping = {}

def get_sector(ticker):
    return sector_mapping.get(str(ticker).strip(), 'Другое')

# -------------------- ОТБОР ТИКЕРОВ ПО СЕКТОРУ --------------------
all_tickers = set()
for df in yearly_dfs.values():
    all_tickers.update(df.index)
all_tickers = sorted(all_tickers)

# Сопоставляем тикеры с секторами
ticker_sector = {ticker: get_sector(ticker) for ticker in all_tickers}

# Выбираем тикеры, входящие в SECTOR_LIST
selected_tickers = [t for t in all_tickers if ticker_sector[t] in SECTOR_LIST]
print(f"\nТикеры сектора {SECTOR_LIST}: {selected_tickers}")

if not selected_tickers:
    raise ValueError("Нет тикеров для выбранного сектора. Проверьте SECTOR_LIST и файл с секторами.")

# -------------------- ПОСТРОЕНИЕ ГРАФИКОВ ДЛЯ КАЖДОГО ПОКАЗАТЕЛЯ --------------------
os.makedirs(OUTPUT_PATH, exist_ok=True)
timestamp = datetime.now().strftime('%d%m%y_%H%M')

# Для каждого показателя создадим отдельный рисунок
for metric in METRICS:
    print(f"\nОбработка показателя: {metric}")
    
    # Собираем данные по годам для выбранных тикеров
    data = []
    for year in YEARS:
        df_year = yearly_dfs.get(year)
        if df_year is None or df_year.empty:
            continue
        if metric not in df_year.columns:
            print(f"  Показатель {metric} отсутствует в {year} году")
            continue
        # Извлекаем значения для отобранных тикеров
        for ticker in selected_tickers:
            if ticker in df_year.index:
                val = df_year.loc[ticker, metric]
                if pd.notna(val) and val not in [np.inf, -np.inf]:
                    data.append({
                        'Год': year,
                        'Тикер': ticker,
                        metric: val
                    })
    if not data:
        print(f"  Нет данных для {metric}, пропускаем")
        continue
    
    df_plot = pd.DataFrame(data)
    
    # Определяем количество тикеров и подбираем размер графика
    n_tickers = len(df_plot['Тикер'].unique())
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # --- Левый график: линейный (динамика по годам для каждого тикера) ---
    ax1 = axes[0]
    sns.lineplot(data=df_plot, x='Год', y=metric, hue='Тикер', marker='o', ax=ax1, palette='tab10')
    ax1.set_title(f'Динамика {metric} по годам\nСектор: {SECTOR_LIST[0]}', fontsize=12)
    ax1.set_xlabel('Год')
    ax1.set_ylabel(metric)
    ax1.legend(title='Тикер', bbox_to_anchor=(1.05, 1), loc='upper left')
    ax1.grid(True, alpha=0.3)
    
    # --- Правый график: столбчатая диаграмма (сравнение тикеров по годам) ---
    ax2 = axes[1]
    # Сгруппируем по годам и тикерам, построим grouped bar chart
    pivot_df = df_plot.pivot(index='Год', columns='Тикер', values=metric)
    pivot_df.plot(kind='bar', ax=ax2, width=0.8)
    ax2.set_title(f'Сравнение {metric} по годам\nСектор: {SECTOR_LIST[0]}', fontsize=12)
    ax2.set_xlabel('Год')
    ax2.set_ylabel(metric)
    ax2.legend(title='Тикер', bbox_to_anchor=(1.05, 1), loc='upper left')
    ax2.grid(axis='y', alpha=0.3)
    
    plt.suptitle(f'Анализ показателя: {metric}', fontsize=14, fontweight='bold')
    plt.tight_layout()
    
    # Сохраняем график
    filename = f'{metric}_dynamics_{SECTOR_LIST[0].replace(" ", "_")}_{timestamp}.png'
    filepath = os.path.join(OUTPUT_PATH, filename)
    plt.savefig(filepath, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"  График сохранён: {filepath}")

    # Вывод описания показателя (можно добавить в легенду или отдельно)
    descriptions = {
        'Revenue': 'Выручка — общий доход компании от реализации продукции/услуг.',
        'OperatingProfit': 'Операционная прибыль — прибыль от основной деятельности до вычета процентов и налогов.',
        'EBITDA': 'Прибыль до вычета процентов, налогов, износа и амортизации — показатель операционной эффективности.',
        'NetIncome': 'Чистая прибыль — конечный финансовый результат.',
        'CAPEX': 'Капитальные затраты — инвестиции в основные средства.',
        'FCF': 'Свободный денежный поток — денежные средства, доступные после инвестиций.',
        'OperExpenses': 'Операционные расходы — затраты на основную деятельность.',
        'Interest': 'Процентные расходы — затраты на обслуживание долга.',
        'Assets': 'Активы — всё, чем владеет компания.',
        'Debt': 'Долг — общая сумма заёмных средств.',
        'Cash': 'Денежные средства и их эквиваленты.',
        'NetDebt': 'Чистый долг (Долг минус Денежные средства).',
        'Price': 'Цена акции.',
        'Shares': 'Количество акций в обращении.',
        'MarketCap': 'Рыночная капитализация (Цена × Количество акций).',
        'EPS': 'Прибыль на акцию.',
        'BVPS': 'Балансовая стоимость на акцию.',
        'ROE_raw': 'Рентабельность собственного капитала (Чистая прибыль / Собственный капитал).',
        'ROA_raw': 'Рентабельность активов (Чистая прибыль / Активы).',
        'PE_raw': 'Цена / Прибыль — мультипликатор, показывающий сколько лет потребуется для окупаемости инвестиции за счёт прибыли.',
        'PS_raw': 'Цена / Выручка — оценка стоимости компании относительно выручки.',
        'PB_raw': 'Цена / Балансовая стоимость — сравнение рыночной и балансовой стоимости.',
        'EVEBITDA_raw': 'Стоимость компании (EV) / EBITDA — показатель сравнительной оценки.',
        'DebtEBITDA_raw': 'Чистый долг / EBITDA — показатель долговой нагрузки.'
    }
    desc = descriptions.get(metric, 'Нет описания.')
    print(f"  Описание: {desc}\n")

print(f"\nАнализ завершён. Все графики сохранены в папку: {OUTPUT_PATH}")
# Out:
# Загрузка годовых данных...
#   2020: 98 строк, 27 колонок
#   2021: 98 строк, 27 колонок
#   2022: 98 строк, 27 колонок
#   2023: 98 строк, 27 колонок
#   2024: 98 строк, 27 колонок
#   2025: 98 строк, 27 колонок
#
# Загрузка секторов...
# Загружено 260 записей о секторах.
#
# Тикеры сектора ['Агропром, химия']: ['ABRD', 'AKRN', 'AQUA', 'GCHE', 'KAZT', 'KLVZ', 'NKHP', 'PHOR', 'RAGR']
#
# Обработка показателя: Revenue
#   График сохранён: C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Analitika/Revenue_dynamics_Агропром,_химия_150326_2233.png
#   Описание: Выручка — общий доход компании от реализации продукции/услуг.
#
#
# Обработка показателя: OperatingProfit
#   График сохранён: C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Analitika/OperatingProfit_dynamics_Агропром,_химия_150326_2233.png
#   Описание: Операционная прибыль — прибыль от основной деятельности до вычета процентов и налогов.
#
#
# Обработка показателя: EBITDA
# ...
