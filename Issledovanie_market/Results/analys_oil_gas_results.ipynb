# %% [markdown]
# # Аналитический отчёт по результатам фундаментального скрининга сектора Нефти и газа
#
# **Дата анализа:** 16 марта 2026 г.
# **Выборка:** 6 крупнейших компаний нефтегазового сектора, прошедших фильтр ликвидности (оборот ≥ 1 млн руб., заявки ≥ 100).
# **Фавориты (выбраны пользователем):** **BANE, LKOH, NVTK, ROSN, SNGS, TATN**.
#
# ## 1. Введение
#
# Цель анализа – оценка инвестиционной привлекательности ведущих компаний российского нефтегазового сектора, представленных в файле и отобранных пользователем. В выборку вошли как вертикально-интегрированные холдинги с собственной переработкой и сбытом, так и компании, специализирующиеся на добыче и производстве сжиженного природного газа.
#
# В работе использованы данные из предоставленного файла (исторические данные за 2020-2025 гг. и последние 12 месяцев – LTM), а также актуальная информация из открытых источников для оценки перспектив компаний на ближайшие 3 года.
#
# ## 2. Краткое описание компаний
#
# | Тикер | Название | Основная деятельность |
# |-------|----------|----------------------|
# | **BANE** | Башнефть | Вертикально-интегрированная компания с активами в Башкирии, Татарстане, ЯНАО и ХМАО. Контролируется «Роснефтью» (57,7%), около 25% акций у правительства Башкортостана |
# | **LKOH** | Лукойл | Крупнейшая частная нефтегазовая компания России с полным циклом производства, высокой долей переработки и сетью АЗС |
# | **NVTK** | Новатэк | Крупнейший независимый производитель природного газа в России, лидер в производстве СПГ |
# | **ROSN** | Роснефть | Крупнейшая государственная нефтегазовая компания России, лидер по объёмам добычи и переработки |
# | **SNGS** | Сургутнефтегаз | Вертикально-интегрированная компания с уникальной структурой капитала и крупнейшей валютной «кубышкой» (депозиты в валюте) |
# | **TATN** | Татнефть | Крупная нефтяная компания с высокой долей переработки, стабильной дивидендной историей и развитым нефтехимическим комплексом |
#
# ## 3. Детальный анализ фаворитов
#
# ### 3.1. BANE (Башнефть)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | -25.2 | 2.77 | 21.2 | 2.12 | 4.01 | - | 4.01 |
# | P/B | 0.6 | 0.42 | - | 0.45 | 0.47 | - | 0.47 |
# | EV/EBITDA | 12.5 | 2.29 | - | 1.55 | 2.22 | - | 2.22 |
# | NetDebt/EBITDA | 3.82 | 0.83 | - | 0 | 0 | - | 0 |
# | ROE, % | -2.4 | 15 | - | 21.3 | 11.7 | - | 11.7 |
# | ROA, % | -1.4 | 9.1 | - | 15.7 | 9 | - | 9 |
#
# ![image.png](attachment:image.png)
#
# **Анализ динамики:**
# Компания демонстрирует высокую волатильность финансовых показателей. В 2020 году был зафиксирован убыток (отрицательный P/E), однако в 2021-2023 годах рентабельность значительно выросла благодаря благоприятной ценовой конъюнктуре. В 2024 году чистая прибыль сократилась на 42% до 103,9 млрд руб. при росте выручки на 11%. Долговая нагрузка остаётся нулевой с 2023 года.
#
# **Свежие данные и перспективы:**
# По данным на март 2026 года, дивидендная доходность по обыкновенным акциям составляет около 8,5%, по привилегированным — около 13,2%. Компания сохраняет высокую долю внутренних продаж, что снижает валютные и экспортные риски. Однако прозрачность бизнеса остаётся низкой: операционная отчётность не публикуется, квартальные результаты не раскрываются.
#
# Правительство Башкортостана планирует продать 11,3 млн акций (около 6,4% уставного капитала), что может оказать давление на котировки. Ожидаемая дата следующего отчёта — 19 марта 2026 года.
#
# **Вывод по тикеру:**
# Башнефть – государственный актив с низким долгом и стабильными дивидендами, но крайне низкой прозрачностью. Привилегированные акции выглядят значительно интереснее обыкновенных из-за более высокой дивидендной доходности. Рекомендуется для дивидендных инвесторов с пониманием корпоративных рисков.
#
# ### 3.2. LKOH (Лукойл)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 222.5 | 5.51 | 3.57 | 4.06 | 5.91 | - | 6.35 |
# | P/B | 0.83 | 0.95 | - | 0.74 | 0.75 | - | 0.75 |
# | EV/EBITDA | 5.38 | 3.1 | - | 1.95 | 2.17 | - | 2.64 |
# | NetDebt/EBITDA | 0.46 | 0.06 | - | -0.39 | -0.64 | - | -0.16 |
# | ROE, % | 0.4 | 17.1 | - | 18.1 | 12.4 | - | 9.06 |
# | ROA, % | 0.3 | 11.3 | - | 13.4 | 9.1 | - | 6.05 |
#
# ![image-2.png](attachment:image-2.png)
#
# **Анализ динамики:**
# Лукойл традиционно отличается финансовой устойчивостью и низкой долговой нагрузкой. С 2021 года компания имеет отрицательный чистый долг (денежные средства превышают обязательства). P/E достигал минимума в 2022-2023 годах (3.6-4.1), затем вырос до текущих 6.35, что соответствует справедливой оценке. Рентабельность капитала остаётся на здоровом уровне (9-12%).
#
# **Свежие данные и перспективы:**
# По итогам 9 месяцев 2025 года чистая прибыль снизилась на 14,3% до 352 млрд руб., операционная маржа сохраняется около 19%. Утверждены дивиденды в 397 руб. на акцию (доходность ~6,8%), компания направляет на дивиденды 100% скорректированного свободного денежного потока.
#
# Однако компания столкнулась с серьёзными вызовами в начале 2026 года: крупнейший зарубежный актив «Западная Курна-2» в Ираке перешёл под управление Ирака, санкционное давление требует продажи зарубежных активов до 17 января 2026 года. Аналитики рекомендуют избегать покупки до разрешения санкционной ситуации.
#
# **Вывод по тикеру:**
# Лукойл сохраняет крепкий баланс и стабильные дивиденды, но потеря иракских активов и санкционное давление создают значительную неопределённость. Рекомендуется выдержать паузу до прояснения ситуации с зарубежными проектами.
#
# ### 3.3. NVTK (Новатэк)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | - | 12.4 | - | 9.63 | 6.08 | 19.7 | 19.3 |
# | P/B | - | 2.76 | - | 1.72 | 1.06 | 1.28 | 1.24 |
# | EV/EBITDA | - | 7.16 | - | 5.02 | 3.12 | 4.15 | 4.06 |
# | NetDebt/EBITDA | - | 0.18 | - | 0.01 | 0.14 | -0.05 | отрицательный |
# | ROE, % | - | 22.2 | - | 17.9 | 17.4 | 6.5 | 6.5 |
# | ROA, % | - | 17.1 | - | 14.4 | 13.2 | 5.1 | 5.1 |
#
# ![image-3.png](attachment:image-3.png)
#
# **Анализ динамики:**
# Новатэк демонстрирует смешанную динамику. В 2022-2024 годах мультипликаторы были на привлекательных уровнях (P/E 6-9.6), однако в 2025 году произошёл резкий скачок P/E до 19.3 на фоне падения чистой прибыли. По итогам 2 полугодия 2025 года получен убыток -41,3 млрд руб. против прибыли 227,3 млрд руб. в 1 полугодии. При этом свободный денежный поток вырос в 2,1 раза до 255,2 млрд руб., появилась чистая денежная позиция.
#
# **Свежие данные и перспективы:**
# Прогнозируемый дивиденд составляет 35,49 руб. на акцию (доходность около 3,06%). Компания сталкивается с серьёзными внешними ограничениями: европейский рынок СПГ переориентируется на США, запуск третьей очереди «Арктик СПГ-2» перенесён на 2028 год, из 21 запланированного танкера ледового класса построено только 2.
#
# **Вывод по тикеру:**
# При текущих сложностях оценка компании не выглядит дешёвой (P/E скорректированный 2025 = 7,1, но рыночный P/E 19,3). Рынок сохраняет оптимизм в отношении Новатэка как потенциального бенефициара геополитического урегулирования. Рекомендуется для долгосрочных инвесторов с горизонтом от 3 лет, готовых к высокой волатильности.
#
# ### 3.4. ROSN (Роснефть)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 27.6 | 6 | 4.74 | 4.6 | 5.92 | - | 5.92 |
# | P/B | 1.02 | 1.18 | - | 0.69 | 0.7 | - | 0.7 |
# | EV/EBITDA | 8.42 | 5.04 | 1.51 | 2.84 | 3.32 | - | 2.21 |
# | NetDebt/EBITDA | 4.58 | 2.32 | 0 | 0.9 | 1.2 | - | 0 |
# | ROE, % | 3.6 | 19.1 | - | 15.1 | 11.8 | - | 4.7 |
# | ROA, % | 1.1 | 6.4 | - | 6.7 | 5.2 | - | 2 |
#
# ![image-4.png](attachment:image-4.png)
#
# **Анализ динамики:**
# Роснефть демонстрирует цикличность, характерную для сектора. В 2022 году благодаря высоким ценам на нефть P/E достигал минимума (1.51), затем нормализовался до 5-6. Долговая нагрузка остаётся под контролем (NetDebt/EBITDA снизился с 4.58 в 2020 году до 0-1.2 в последние периоды). Рентабельность капитала снизилась до 4.7% по LTM данным.
#
# **Свежие данные и перспективы:**
# По данным открытых источников, дивидендная доходность составляет около 5.4%. Компания остаётся системообразующим активом с государственным участием, что обеспечивает поддержку в сложных макроэкономических условиях. Дальнейшие перспективы связаны с динамикой цен на нефть и геополитической ситуацией.
#
# **Вывод по тикеру:**
# Роснефть – стабильный, но не выдающийся актив. Низкая оценка по P/B (0.7) и контролируемый долг делают компанию привлекательной для консервативных инвесторов, однако рентабельность снижается. Рекомендуется для диверсификации в нефтегазовом секторе.
#
# ### 3.5. SNGS (Сургутнефтегаз)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | 2.16 | 2.16 | 3.04 | 0.9 | 0.89 | - | 0.89 |
# | P/B | 0.31 | - | - | 0.17 | 0.17 | - | 0.17 |
# | EV/EBITDA | -8.92 | - | -4.86 | -7.2 | - | - | - |
# | NetDebt/EBITDA | -15.4 | - | -6.17 | -9.39 | - | - | - |
# | ROE, % | 14.4 | - | 5.5 | 18.7 | 18.7 | - | 18.7 |
# | ROA, % | 12.6 | - | 4.9 | 16.4 | 16.4 | - | 16.4 |
#
# ![image-5.png](attachment:image-5.png)
#
# **Анализ динамики:**
# Сургутнефтегаз – уникальная компания с колоссальной валютной «кубышкой» (депозиты в валюте), что приводит к экстремальной волатильности чистой прибыли из-за курсовых разниц. В 2022 году был зафиксирован убыток (отрицательный P/E), в 2023-2024 годах – рекордная прибыль. P/B находится на минимальных уровнях (0.17), что указывает на глубокую недооценку относительно балансовой стоимости.
#
# **Свежие данные и перспективы:**
# За 1 полугодие 2025 года получен убыток 452,7 млрд руб. из-за укрепления рубля, однако дивиденды по привилегированным акциям зависят от прибыли нефтяного бизнеса и доходов от валютной «кубышки». По уставу компания обязана выплачивать не менее 10% чистой прибыли на привилегированные акции. Прогноз дивидендов на 2026 год: 8-14 руб. на акцию (доходность может достигать 16-30% в зависимости от курса доллара).
#
# **Вывод по тикеру:**
# Сургутнефтегаз – ставка на ослабление рубля и высокие дивиденды по префам. Низкая оценка (P/E 0.89, P/B 0.17) создаёт потенциал роста. Рекомендуется для инвесторов, готовых к валютной волатильности, с фокусом на привилегированные акции.
#
# ### 3.6. TATN (Татнефть)
#
# **Динамика ключевых мультипликаторов (2020-2025):**
#
# | Показатель | 2020 | 2021 | 2022 | 2023 | 2024 | 2025 | LTM |
# |------------|------|------|------|------|------|------|-----|
# | P/E | - | 5.83 | 2.84 | 5.77 | 5.24 | 8.48 | 8.48 |
# | P/B | - | 1.23 | 0.74 | 1.39 | 1.21 | 1.02 | 1.02 |
# | EV/EBITDA | - | 3.64 | 1.47 | 4.06 | 3.13 | 4 | 4 |
# | NetDebt/EBITDA | - | -0.44 | -0.34 | -0.16 | -0.22 | -0.1 | -0.1 |
# | ROE, % | - | 21.1 | 26 | 24 | 23.2 | 12 | 12 |
# | ROA, % | - | 13.2 | 17 | 14 | 13.9 | 7.4 | 7.4 |
#
# ![image-6.png](attachment:image-6.png)
#
# **Анализ динамики:**
# Татнефть традиционно отличается стабильностью и умеренной долговой нагрузкой (отрицательный чистый долг на всём периоде). P/E достигал минимума в 2022 году (2.84), затем вырос до 8.48. Рентабельность капитала снизилась с 21-26% в 2021-2023 годах до 12% в 2025-м, что отражает нормализацию цен на нефть и рост издержек.
#
# **Свежие данные и перспективы:**
# Компания сохраняет стабильную дивидендную историю. Последние выплаты составили 8,13 руб. на акцию 8 января 2026 года (доходность 1,42%). За 2025 год совокупные дивиденды могут составить около 98,7 руб. на акцию (доходность ~14-15%).
#
# **Вывод по тикеру:**
# Татнефть – наиболее стабильный представитель сектора с отрицательным долгом и предсказуемой дивидендной политикой. Текущая оценка (P/E 8.5) выглядит справедливой. Рекомендуется для консервативных инвесторов, ориентированных на регулярный дивидендный доход.
#
# ## 4. Сводная таблица мультипликаторов (LTM) и дивидендной доходности
#
# | Тикер | Див. доходность, % | P/E | P/B | EV/EBITDA | NetDebt/EBITDA | ROE, % | ROA, % |
# |-------|-------------------|-----|-----|-----------|----------------|--------|--------|
# | **SNGSP** (преф) | 16.2 | 0.89 | 0.17 | отр. | отр. | 18.7 | 16.4 |
# | **BANEP** (преф) | 14.9 | 4.01 | 0.47 | 2.22 | 0 | 11.7 | 9.0 |
# | **LKOH** | 14.67 | 6.35 | 0.75 | 2.64 | -0.16 | 9.06 | 6.05 |
# | **TATNP** (преф) | 10.45 | 8.48 | 1.02 | 4.0 | -0.1 | 12.0 | 7.4 |
# | **TATN** | 9.95 | 8.48 | 1.02 | 4.0 | -0.1 | 12.0 | 7.4 |
# | **BANE** | 8.7 | 4.01 | 0.47 | 2.22 | 0 | 11.7 | 9.0 |
# | **NVTK** | 6.87 | 19.3 | 1.24 | 4.06 | отр. | 6.5 | 5.1 |
# | **ROSN** | 6.4 | 5.92 | 0.7 | 2.21 | 0 | 4.7 | 2.0 |
#
# ## 5. Выводы и рекомендации
#
# ### 5.1. Лидеры по дивидендной доходности
#
# - **SNGS (Сургутнефтегаз, привилегированные акции)** – абсолютный лидер по потенциалу дивидендной доходности (до 16-30% в зависимости от курса доллара). Уникальная структура с валютной «кубышкой» создаёт высокую волатильность, но и потенциал сверхдоходности при ослаблении рубля.
# - **BANE (Башнефть, привилегированные акции)** – стабильная дивидендная доходность 13.2% при низком долге и государственном контроле. Основной минус – крайне низкая прозрачность.
# - **TATN (Татнефть)** – прогнозируемая дивидендная доходность 14-15% за 2025 год, отрицательный долг и стабильная дивидендная история делают компанию лучшим выбором для консервативных инвесторов.
#
# ### 5.2. Наиболее привлекательные по фундаментальным показателям
#
# - **LKOH (Лукойл)** – крепкий баланс, отрицательный долг, высокая операционная эффективность. Однако санкционные риски и потеря иракских активов требуют осторожности. Рекомендуется выдержать паузу до прояснения ситуации.
# - **TATN (Татнефть)** – лучший баланс в секторе (отрицательный долг), стабильная рентабельность и прозрачная дивидендная политика.
#
# ### 5.3. Умеренный интерес
#
# - **ROSN (Роснефть)** – низкая оценка (P/B 0.7) и контролируемый долг, но снижающаяся рентабельность. Подходит для диверсификации в портфеле.
#
# ### 5.4. Высокорисковые / требующие осторожности
#
# - **NVTK (Новатэк)** – высокая оценка (P/E 19.3) при падении прибыли и серьёзных внешних ограничениях (санкции, потеря рынков сбыта). Рынок сохраняет избыточный оптимизм.
#
# ## 6. Перспективы сектора на 2026-2029 гг.
#
# - **Цены на нефть** – прогнозируются на уровне $60-70 за баррель Brent, что ниже уровней 2022-2023 годов, но достаточно для комфортной рентабельности эффективных производителей.
# - **Курс рубля** – остаётся ключевым фактором для компаний с валютной выручкой. Ослабление рубля поддержит финансовые результаты экспортёров.
# - **Налогообложение** – возможны корректировки НДПИ и демпферного механизма, что создаёт неопределённость для отрасли.
# - **Санкционные риски** – ограничения на поставки оборудования и технологий, а также санкции против СПГ-проектов остаются ключевыми рисками для NVTK и отраслевых проектов в Арктике.
# - **Сделка ОПЕК+** – квоты на добычу продолжат ограничивать возможности роста производства для всех компаний сектора.
#
# ## 7. Когда произвести очередной скрининг?
#
# Рекомендуется провести следующий скрининг **через 6 месяцев (сентябрь 2026)** с акцентом на:
#
# - разрешение санкционной ситуации для LKOH и динамику потери зарубежных активов;
# - реализацию дивидендных прогнозов SNGS и TATN;
# - способность NVTK адаптироваться к санкционным ограничениям и ход строительства СПГ-проектов;
# - динамику долговой нагрузки и рентабельности ROSN;
# - макроэкономические сигналы (цены на нефть, курс рубля, ключевая ставка, решения ОПЕК+).
#
# ---

# %%
# =============================================================================
# БЛОК АНАЛИЗА ДИНАМИКИ МУЛЬТИПЛИКАТОРОВ ПО СЕКТОРУ (2020-2025)
# =============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import os
import warnings
warnings.filterwarnings('ignore')

# -------------------- НАСТРОЙКИ --------------------
YEARS = [2020, 2021, 2022, 2023, 2024, 2025]  # анализируемые годы
INPUT_YEARLY_FILE = 'C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/df_fund_yearly.xlsx'
SECTOR_FILE = 'C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Sector_updated.xlsx'  # файл с секторами
OUTPUT_PATH = 'C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Analitika/'
SECTOR_LIST = [
    'Добыча нефти и газа'
]

# Список показателей для анализа (расширенный, включая дивидендную доходность)
METRICS = [
    'DivYield_ao', 'DivYield_ap', 'Revenue', 'OperatingProfit', 'EBITDA', 'NetIncome',
    'CAPEX', 'FCF', 'OperExpenses', 'Interest',
    'Assets', 'Debt', 'Cash', 'NetDebt',
    'Price', 'Shares', 'MarketCap', 'EPS', 'BVPS',
    'ROE_raw', 'ROA_raw', 'PE_raw', 'PS_raw', 'PB_raw',
    'EVEBITDA_raw', 'DebtEBITDA_raw'
]

# -------------------- ЗАГРУЗКА ДАННЫХ --------------------
print("Загрузка годовых данных...")
yearly_dfs = {}
for year in YEARS:
    try:
        df_year = pd.read_excel(INPUT_YEARLY_FILE, sheet_name=str(year), index_col=0, engine='openpyxl')
        # Убираем возможный дублирующийся индекс, если колонка 'A' попала как данные
        if 'A' in df_year.columns:
            df_year = df_year.drop(columns=['A'])

        # --- Добавление дивидендной доходности, если есть Dividend и Price ---
        if 'Dividend' in df_year.columns and 'Price' in df_year.columns:
            mask = (df_year['Price'] > 0) & df_year['Dividend'].notna()
            df_year.loc[mask, 'DivYield'] = df_year.loc[mask, 'Dividend'] / df_year.loc[mask, 'Price'] * 100
            # print(f"    Рассчитана DivYield для {year} года")
        else:
            # Если нет данных, колонка всё равно может отсутствовать – это нормально
            pass

        yearly_dfs[year] = df_year
        print(f"  {year}: {df_year.shape[0]} строк, {df_year.shape[1]} колонок")
    except Exception as e:
        print(f"  Ошибка загрузки листа {year}: {e}")
        yearly_dfs[year] = pd.DataFrame()

# -------------------- ЗАГРУЗКА СЕКТОРОВ --------------------
print("\nЗагрузка секторов...")
try:
    sector_df = pd.read_excel(SECTOR_FILE, sheet_name='Sector', engine='openpyxl')
    sector_df = sector_df[['Код инструмента', 'Категории']].copy()
    sector_df.dropna(inplace=True)
    sector_df['Код инструмента'] = sector_df['Код инструмента'].astype(str).str.strip()
    sector_df = sector_df.drop_duplicates(subset=['Код инструмента'])
    sector_mapping = dict(zip(sector_df['Код инструмента'], sector_df['Категории']))
    print(f"Загружено {len(sector_mapping)} записей о секторах.")
except Exception as e:
    print(f"Ошибка загрузки секторов: {e}")
    sector_mapping = {}

def get_sector(ticker):
    return sector_mapping.get(str(ticker).strip(), 'Другое')

# -------------------- ОТБОР ТИКЕРОВ ПО СЕКТОРУ --------------------
all_tickers = set()
for df in yearly_dfs.values():
    all_tickers.update(df.index)
all_tickers = sorted(all_tickers)

# Сопоставляем тикеры с секторами
ticker_sector = {ticker: get_sector(ticker) for ticker in all_tickers}

# Выбираем тикеры, входящие в SECTOR_LIST
selected_tickers = [t for t in all_tickers if ticker_sector[t] in SECTOR_LIST]
print(f"\nТикеры сектора {SECTOR_LIST}: {selected_tickers}")

if not selected_tickers:
    raise ValueError("Нет тикеров для выбранного сектора. Проверьте SECTOR_LIST и файл с секторами.")

# -------------------- ПОСТРОЕНИЕ ГРАФИКОВ ДЛЯ КАЖДОГО ПОКАЗАТЕЛЯ --------------------
os.makedirs(OUTPUT_PATH, exist_ok=True)
timestamp = datetime.now().strftime('%d%m%y_%H%M')

# Для каждого показателя создадим отдельный рисунок
for metric in METRICS:
    print(f"\nОбработка показателя: {metric}")

    # Собираем данные по годам для выбранных тикеров
    data = []
    for year in YEARS:
        df_year = yearly_dfs.get(year)
        if df_year is None or df_year.empty:
            continue
        if metric not in df_year.columns:
            # Если метрики нет, пропускаем (например, DivYield может быть не во всех годах)
            continue
        # Извлекаем значения для отобранных тикеров
        for ticker in selected_tickers:
            if ticker in df_year.index:
                val = df_year.loc[ticker, metric]
                if pd.notna(val) and val not in [np.inf, -np.inf]:
                    data.append({
                        'Год': year,
                        'Тикер': ticker,
                        metric: val
                    })
    if not data:
        print(f"  Нет данных для {metric}, пропускаем")
        continue

    df_plot = pd.DataFrame(data)

    # Определяем количество тикеров и подбираем размер графика
    n_tickers = len(df_plot['Тикер'].unique())
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # --- Левый график: линейный (динамика по годам для каждого тикера) ---
    ax1 = axes[0]
    sns.lineplot(data=df_plot, x='Год', y=metric, hue='Тикер', marker='o', ax=ax1, palette='tab10')
    ax1.set_title(f'Динамика {metric} по годам\nСектор: {SECTOR_LIST[0]}', fontsize=12)
    ax1.set_xlabel('Год')
    ax1.set_ylabel(metric)
    ax1.legend(title='Тикер', bbox_to_anchor=(1.05, 1), loc='upper left')
    ax1.grid(True, alpha=0.3)

    # --- Правый график: столбчатая диаграмма (сравнение тикеров по годам) ---
    ax2 = axes[1]
    # Сгруппируем по годам и тикерам, построим grouped bar chart
    pivot_df = df_plot.pivot(index='Год', columns='Тикер', values=metric)
    pivot_df.plot(kind='bar', ax=ax2, width=0.8)
    ax2.set_title(f'Сравнение {metric} по годам\nСектор: {SECTOR_LIST[0]}', fontsize=12)
    ax2.set_xlabel('Год')
    ax2.set_ylabel(metric)
    ax2.legend(title='Тикер', bbox_to_anchor=(1.05, 1), loc='upper left')
    ax2.grid(axis='y', alpha=0.3)

    plt.suptitle(f'Анализ показателя: {metric}', fontsize=14, fontweight='bold')
    plt.tight_layout()

    # Сохраняем график
    filename = f'{metric}_dynamics_{SECTOR_LIST[0].replace(" ", "_")}_{timestamp}.png'
    filepath = os.path.join(OUTPUT_PATH, filename)
    plt.savefig(filepath, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"  График сохранён: {filepath}")

    # Вывод описания показателя
    descriptions = {
        'Revenue': 'Выручка — общий доход компании от реализации продукции/услуг.',
        'OperatingProfit': 'Операционная прибыль — прибыль от основной деятельности до вычета процентов и налогов.',
        'EBITDA': 'Прибыль до вычета процентов, налогов, износа и амортизации — показатель операционной эффективности.',
        'NetIncome': 'Чистая прибыль — конечный финансовый результат.',
        'CAPEX': 'Капитальные затраты — инвестиции в основные средства.',
        'FCF': 'Свободный денежный поток — денежные средства, доступные после инвестиций.',
        'OperExpenses': 'Операционные расходы — затраты на основную деятельность.',
        'Interest': 'Процентные расходы — затраты на обслуживание долга.',
        'Assets': 'Активы — всё, чем владеет компания.',
        'Debt': 'Долг — общая сумма заёмных средств.',
        'Cash': 'Денежные средства и их эквиваленты.',
        'NetDebt': 'Чистый долг (Долг минус Денежные средства).',
        'Price': 'Цена акции.',
        'Shares': 'Количество акций в обращении.',
        'MarketCap': 'Рыночная капитализация (Цена × Количество акций).',
        'EPS': 'Прибыль на акцию.',
        'BVPS': 'Балансовая стоимость на акцию.',
        'ROE_raw': 'Рентабельность собственного капитала (Чистая прибыль / Собственный капитал).',
        'ROA_raw': 'Рентабельность активов (Чистая прибыль / Активы).',
        'PE_raw': 'Цена / Прибыль — мультипликатор, показывающий сколько лет потребуется для окупаемости инвестиции за счёт прибыли.',
        'PS_raw': 'Цена / Выручка — оценка стоимости компании относительно выручки.',
        'PB_raw': 'Цена / Балансовая стоимость — сравнение рыночной и балансовой стоимости.',
        'EVEBITDA_raw': 'Стоимость компании (EV) / EBITDA — показатель сравнительной оценки.',
        'DebtEBITDA_raw': 'Чистый долг / EBITDA — показатель долговой нагрузки.',
        'DivYield_ao': 'Дивидендная доходность (обычные акции) = Дивиденд на акцию / Цена акции × 100%. Показывает, сколько процентов от текущей цены акции составляют годовые дивиденды.',
        'DivYield_ap': 'Дивидендная доходность (привелегированные акции) = Дивиденд на акцию / Цена акции × 100%. Показывает, сколько процентов от текущей цены акции составляют годовые дивиденды.'
    }
    desc = descriptions.get(metric, 'Нет описания.')
    print(f"  Описание: {desc}\n")

print(f"\nАнализ завершён. Все графики сохранены в папку: {OUTPUT_PATH}")
# Out:
# Загрузка годовых данных...
#   2020: 98 строк, 30 колонок
#   2021: 98 строк, 30 колонок
#   2022: 98 строк, 30 колонок
#   2023: 98 строк, 30 колонок
#   2024: 98 строк, 30 колонок
#   2025: 98 строк, 30 колонок
#
# Загрузка секторов...
# Загружено 260 записей о секторах.
#
# Тикеры сектора ['Добыча нефти и газа']: ['BANE', 'LKOH', 'NVTK', 'ROSN', 'SNGS', 'TATN']
#
# Обработка показателя: DivYield_ao
#   График сохранён: C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Analitika/DivYield_ao_dynamics_Добыча_нефти_и_газа_160326_2140.png
#   Описание: Дивидендная доходность (обычные акции) = Дивиденд на акцию / Цена акции × 100%. Показывает, сколько процентов от текущей цены акции составляют годовые дивиденды.
#
#
# Обработка показателя: DivYield_ap
#   График сохранён: C:/Users/1/Documents/TRADE_2026/ScriptsAnalizTorgy/Analitika/DivYield_ap_dynamics_Добыча_нефти_и_газа_160326_2140.png
# ...
